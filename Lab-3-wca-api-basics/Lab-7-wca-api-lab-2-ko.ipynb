# %% [markdown]
# # Lab 2: WCA API로 다중 파일 설명 및 요구사항 기반 코드 생성

# %%
from wca_utils import *
from pathlib import Path

# %% [markdown]
# ### Lab 2.1. 프로젝트 내 여러 파일에 대한 설명 생성

# %%
file_dict = ["assets/Library System Project/Admin.py", "assets/Library System Project/Book.py", "assets/Library System Project/main.py", "assets/Library System Project/OperationsManager.py", "assets/Library System Project/User.py", "assets/Library System Project/utility.py"]

# %%
# sample
text = """
Generate a detailed explanation report about the python project.\
Make sure to include following things in your report:\
1. Business purpose of the project\
2. Simple explanation of each file\
3. Consolidate explanation of the entire project
"""
payload = build_basic_prompt_paylod(text)
response = call_wca_url(payload=payload, apikey=iam_apikey, file_dict=file_dict)
result = (response['response']['message']['content'])
print(result)
# Out:
# **Project Report: Library Management System**
#
# **1. Business Purpose of the Project**
#
# The primary objective of this Python project is to develop a simple yet effective Library Management System. This system allows users to manage books and users within a library, including adding books, printing book lists, searching for books by name, adding users, borrowing and returning books, and printing lists of users and their borrowed books.
#
# **2. Detailed Explanation of Each File**
#
# **2.1 `input_is_valid.py`**
#
# This file contains a utility function `input_is_valid` that validates user input. It ensures that the input is a decimal number within a specified range (if provided). The function repeatedly prompts the user for input until a valid response is received.
#
# **2.2 `user.py`**
#
# The `User` class in this file represents a user of the library. It has two attributes: `id` and `name`. The class constructor `__init__` initializes these attributes.
#
# **2.3 `operations_manager.py`**
#
# This file contains the `OperationsManager` class, which serves as the main interface for the Library Management System. It interacts with the `Admin` class to perform various operations.
#
# - `__init__`: Initializes an instance of the `Admin` class.
# - `print_menu`: Displays a menu of available options and returns the user's choice.
# - `get_choice`: A helper function to get a valid choice from the user within a specified range.
# - `add_book`: Prompts the user to enter details of a new book and adds it to the library using the `Admin` class.
# - `print_books`: Prints all books in the library using the `Admin` class.
# - `search_books`: Allows the user to search for books by name and prints the matching results.
# - `add_user`: Prompts the user to enter details of a new user and adds them to the library using the `Admin` class.
# - `borrow_book`: Allows the user to borrow a book by entering the book name and their name.
# - `return_book`: Allows the user to return a borrowed book by entering the book name and their name.
# - `print_users_borrowed`: Prints all books currently borrowed by users.
# - `print_all_users`: Prints all users in the library.
# - `run`: The main function that drives the program by presenting a menu, processing user choices, and calling appropriate methods.
#
# **3. Consolidated Explanation of the Entire Project**
#
# The Library Management System is designed to manage books and users within a library. The `User` class represents library users, while the `Admin` class (imported from `Admin.py`) manages the library's books and users.
#
# The `OperationsManager` class acts as the user interface, presenting a menu of options to the user and processing their choices. It interacts with the `Admin` class to perform operations such as adding books or users, printing book lists, searching for books, borrowing and returning books, and displaying lists of borrowed books and all users.
#
# The `input_is_valid` function ensures that user inputs are valid, particularly when specifying ranges or decimal numbers.
#
# The system's modular design allows for easy expansion or modification of functionalities. For instance, additional features like overdue book tracking or fine calculation could be added by extending the `Admin` class.
#
# In summary, this Library Management System provides a user-friendly interface for managing a library's books and users, ensuring data integrity through input validation, and offering a range of functionalities to support library operations.

# %% [markdown]
# #### Lab 2.2. 비즈니스 요구사항 문서를 기반으로 프론트엔드/백엔드 코드 생성

# %%
# 비즈니스 요구 사항을 읽고 프롬프트에 언급된 대로 요구 사항을 추출합니다.
file_path = Path("./business-requirement.md") 
spec = read_file(file_path)
requirements = analyze_requirements(spec)
requirement_extract = (requirements['response']['message']['content'])
print("-------extracted requirement-------")
print(requirement_extract)
# Out:
# -------extracted requirement-------
# ```
# # Assisted by watsonx Code Assistant
# {
#     "frontend": {
#         "framework": "React.js",
#         "pages": [
#             "File Upload Component",
#             "File List Component",
#             "File Processing Component",
#             "File Download Component",
#             "User Authentication Components",
#             "Navigation Component",
#             "Main Dashboard Component"
#         ]
#     },
#     "backend": {
#         "api-endpoints": [
#             {
#                 "api-endpoint": "POST /api/upload",
#                 "api-endpoint-details": "Receives files from the frontend, saves files to a designated directory, and initiates processing if required."
#             },
#             {
#                 "api-endpoint": "POST /api/process/<file_id>",
#                 "api-endpoint-details": "Processes the uploaded file based on predefined algorithms and updates file status in the database."
#             },
#             {
#                 "api-endpoint": "GET /api/download/<file_id>",
#                 "api-endpoint-details": "Retrieves the processed file and sends it to the client for download."
#             },
#             {
#                 "api-endpoint": "GET /api/files",
#                 "api-endpoint-details": "Returns a list of files associated with the authenticated user."
#             },
#             {
#                 "api-endpoint": "POST /api/login",
#                 "api-endpoint-details": "Handles user login process."
#             },
#             {
#                 "api-endpoint": "POST /api/register",
#                 "api-endpoint-details": "Handles user registration process."
#             },
#             {
#                 "api-endpoint": "POST /api/logout",
#                 "api-endpoint-details": "Handles user logout process."
#             }
#         ]
#     },
#     "infrastructure": {
#         "containerization": "Docker",
#         "hosting": "Cloud hosting platform (e.g., AWS, Google Cloud, or Heroku)"
#     }
# }
# ```

# %%
# 상용구 백엔드 코드 생성
back_end_code  = generate_backend_code(spec=spec, backend_specs=requirement_extract
                                       )
print("---------backend code---------")
back_end_code = back_end_code['response']['message']['content']
print(back_end_code)
# Out:
# ---------backend code---------
# Here's a basic implementation of the FastAPI backend endpoints as per your specifications. This example assumes you have a SQLite database for storing user information and file metadata, and a directory for storing the files. For simplicity, file processing is not implemented here.
#
# ```python
# # Assisted by watsonx Code Assistant
# from fastapi import FastAPI, Depends, HTTPException, status
# from fastapi.security import OAuth2PasswordBearer, OAuth2PasswordRequestForm
# from pydantic import BaseModel
# from typing import Optional
# import os
# import sqlite3
# from datetime import datetime
#
# app = FastAPI()
#
# # Database connection
# DATABASE = "database.db"
#
# def get_db():
#     db = sqlite3.connect(DATABASE)
#     db.row_factory = sqlite3.Row
#     return db
#
# # OAuth2 for user authentication
# oauth2_scheme = OAuth2PasswordBearer(tokenUrl="token")
#
# class Token(BaseModel):
#     access_token: str
#     token_type: str
#
# class User(BaseModel):
#     username: str
#     password: str
#
# class File(BaseModel):
#     file_id: str
#     filename: str
#     file_path: str
#     status: str = "Pending"
#
# users = {}
# files = {}
#
# @app.post("/api/register")
# async def register_user(user: User):
#     hashed_password = hash_password(user.password)
#     with get_db() as db:
#         cursor = db.cursor()
#         cursor.execute("INSERT INTO users (username, password) VALUES (?, ?)", (user.username, hashed_password))
#         db.commit()
#     return {"message": "User created successfully"}
#
# @app.post("/api/login")
# async def login_for_access_token(form_data: OAuth2PasswordRequestForm = Depends()):
#     user = get_user(form_data.username)
#     if not user:
#         raise HTTPException(
#             status_code=status.HTTP_400_BAD_REQUEST,
#             detail="Incorrect username or password",
#             headers={"WWW-Authenticate": "Bearer"},
#         )
#     if not check_password(form_data.password, user["password"]):
#         raise HTTPException(
#             status_code=status.HTTP_400_BAD_REQUEST,
#             detail="Incorrect username or password",
#             headers={"WWW-Authenticate": "Bearer"},
#         )
#     access_token_expires = datetime.utcnow() + timedelta(minutes=30)
#     access_token = create_access_token(data={"sub": user["username"]}, expires_delta=access_token_expires)
#     return {"access_token": access_token, "token_type": "bearer"}
#
# @app.post("/api/upload")
# async def upload_file(file: bytes = File(...), file_id: str = Depends(generate_file_id)):
#     with get_db() as db:
#         cursor = db.cursor()
#         cursor.execute("INSERT INTO files (file_id, filename) VALUES (?, ?)", (file_id, file.filename))
#         db.commit()
#     file_path = f"uploads/{file_id}"
#     with open(file_path, "wb") as f:
#         f.write(file)
#     files[file_id] = File(file_id=file_id, filename=file.filename, file_path=file_path)
#     return {"message": "File uploaded successfully"}
#
# @app.get("/api/files", response_model=List[File])
# async def get_files(current_user: str = Depends(get_current_user)):
#     with get_db() as db:
#         cursor = db.cursor()
#         cursor.execute("SELECT * FROM files WHERE user_id = ?", (current_user,))
#         files_list = cursor.fetchall()
#     return [File(**file) for file in files_list]
#
# @app.get("/api/download/{file_id}", response_class=FileResponse)
# async def download_file(file_id: str):
#     if file_id not in files:
#         raise HTTPException(status_code=404, detail="File not found")
#     file = files[file_id]
#     return FileResponse(file.file_path)
#
# def get_user(username: str):
#     return users.get(username)
#
# def hash_password(password: str):
#     # Implement your password hashing logic here
#     return password
#
# def check_password(plain_password: str, hashed_password: str):
#     # Implement your password verification logic here
#     return plain_password == hashed_password
#
# def generate_file_id():
#     # Implement your file ID generation logic here
#     return "file_id"
#
# def get_current_user(token: str = Depends(oauth2_scheme)):
#     credentials_exception = HTTPException(
#         status_code=status.HTTP_401_UNAUTHORIZED,
#         detail="Could not validate credentials",
#         headers={"WWW-Authenticate": "Bearer"},
#     )
#     try:
#         payload = oauth2_scheme.decode_token(token).get("sub")
#     except credentials_exception:
#         raise credentials_exception
#     user = get_user(payload)
#     if user is None:
#         raise credentials_exception
#     return payload
#
# from fastapi.responses import FileResponse
# from datetime import timedelta
# import jwt
#
# def create_access_token(data: dict, expires_delta: timedelta = None):
#     to_encode = data.copy()
#     if expires_delta:
#         expire = datetime.utcnow() + expires_delta
#     else:
#         expire = datetime.utcnow() + timedelta(minutes=15)
#     to_encode.update({"exp": expire})
#     encoded_jwt = jwt.encode(to_encode, "SECRET_KEY", algorithm="HS256")
#     return encoded_jwt
# ```
#
# This code provides a basic structure for the specified API endpoints. You'll need to implement the actual file processing logic, password hashing, and file ID generation according to your specific requirements. Also, remember to replace "SECRET_KEY" with a secure secret key for JWT token signing.
#
# Please note that this is a simplified example and does not include error handling, input validation, or security measures that would be necessary for a production application.

# %%
#상용구 프론트엔드 코드 생성
front_end_code_components  = generate_frontend_code(spec=spec, front_end_specs=requirement_extract,
                                                    front_end_framework=None,
                                                    back_end_points=back_end_code)
print("---------frontend code components---------")
print(front_end_code_components['response']['message']['content'])


front_end_code  = generate_frontend_code_detailed(spec=spec, front_end_specs=front_end_code_components['response']['message']['content'], back_end_points=back_end_code)
print("---------frontend code boilerplate---------")
print(front_end_code['response']['message']['content'])
# Out:
# ---------frontend code components---------
# Component Breakdown and Hierarchy:
#
# 1. **Navigation Component**: This component will be responsible for rendering the navigation bar with links to different pages. It will use React Router for navigation.
#
# 2. **User Authentication Components**:
#    - **Login Component**: Handles user login with form submission to the `/api/login` endpoint.
#    - **Register Component**: Handles user registration with form submission to the `/api/register` endpoint.
#    - **Logout Component**: Handles user logout by sending a request to the `/api/logout` endpoint.
#
# 3. **File Upload Component**:
#    - **FileInput Component**: A simple input component for selecting files.
#    - **FileUpload Component**: Handles file selection, sends a POST request to the `/api/upload` endpoint, and manages loading and error states.
#
# 4. **File List Component**:
#    - **FileList Component**: Fetches file data from the `/api/files` endpoint and displays a list of files.
#
# 5. **File Processing Component**:
#    - **FileProcessing Component**: Initiates file processing by sending a POST request to the `/api/process/<file_id>` endpoint.
#
# 6. **File Download Component**:
#    - **FileDownload Component**: Fetches the processed file from the `/api/download/<file_id>` endpoint and initiates a download.
#
# Key Props and State:
#
# - **Navigation Component**: `isAuthenticated` (boolean) to conditionally render login/logout links.
# - **User Authentication Components**: `onLogin`, `onRegister`, `onLogout` (callback functions) for handling form submissions.
# - **File Upload Component**: `files` (array of File objects), `loading` (boolean), `error` (string).
# - **File List Component**: `files` (array of File objects), `loading` (boolean), `error` (string).
# - **File Processing Component**: `fileId` (string), `loading` (boolean), `error` (string).
# - **File Download Component**: `fileId` (string), `loading` (boolean), `error` (string).
#
# Data Flow:
#
# - The `File Upload Component` sends a POST request to the `/api/upload` endpoint to upload files.
# - The `File List Component` fetches file data from the `/api/files` endpoint.
# - The `File Processing Component` sends a POST request to the `/api/process/<file_id>` endpoint to process files.
# - The `File Download Component` fetches the processed file from the `/api/download/<file_id>` endpoint.
#
# API Integration Points:
#
# - `/api/upload`: Used by the `FileUpload Component` to upload files.
# - `/api/process/<file_id>`: Used by the `FileProcessing Component` to process files.
# - `/api/files`: Used by the `FileList Component` to fetch file data.
# - `/api/download/<file_id>`: Used by the `FileDownload Component` to download files.
# - `/api/login`, `/api/register`, `/api/logout`: Used by the User Authentication Components for user authentication.
#
# Error Handling and Loading States:
#
# - Each component will manage its own loading and error states.
# - Error states will be displayed to the user when an API request fails.
# - Loading states will be displayed while waiting for API responses.
#
# Suggested Libraries and Tools:
#
# - **React Router**: For handling navigation between pages.
# - **Axios**: For making HTTP requests to the backend API.
# - **React Hook Form**: For handling form submissions and state management.
# - **React Query**: For managing server state and optimistic updates.
# - **Material-UI**: For pre-built, customizable UI components.
# - **Docker**: For containerizing the application.
# - **Cloud Hosting Platform (e.g., AWS, Google Cloud, or Heroku)**: For deploying the application.
#
# This high-level architecture and implementation plan should provide a solid foundation for building the described React.js application. Each component can be further broken down into smaller, reusable components as needed.
# ---------frontend code boilerplate---------
# Here's a basic implementation of the React.js components based on the provided requirements. This example uses React Router for navigation, Axios for API requests, React Hook Form for form handling, and Material-UI for UI components.
#
# ```jsx
# // Assisted by watsonx Code Assistant
# import React, { useState, useEffect } from 'react';
# import { BrowserRouter as Router, Route, Switch, Link } from 'react-router-dom';
# import axios from 'axios';
# import { useForm } from 'react-hook-form';
# import { Button, Typography, Box, CircularProgress, Alert } from '@material-ui/core';
#
# // Navigation Component
# const Navigation = ({ isAuthenticated }) => (
#   <nav>
#     <Box sx={{ display: 'flex', justifyContent: 'space-between', mb: 2 }}>
#       <Link to="/">Home</Link>
#       {isAuthenticated ? (
#         <>
#           <Link to="/upload">Upload</Link>
#           <Link to="/files">Files</Link>
#           <Link to="/process">Process</Link>
#           <Link to="/download">Download</Link>
#           <Link to="/logout">Logout</Link>
#         </>
#       ) : (
#         <Link to="/login">Login</Link>
#         <Link to="/register">Register</Link>
#       )}
#     </Box>
#   </nav>
# );
#
# // User Authentication Components
# const Login = ({ onLogin }) => {
#   const [formState, setFormState] = useState({ email: '', password: '' });
#   const { register, handleSubmit, errors } = useForm();
#
#   const onSubmit = (data) => {
#     axios.post('/api/login', data).then(onLogin).catch((error) => {
#       alert('Login failed. Please check your credentials.');
#     });
#   };
#
#   return (
#     <form onSubmit={handleSubmit(onSubmit)}>
#       <Typography variant="h6" gutterBottom>Login</Typography>
#       <Box mb={2}>
#         <input {...register('email', { required: true })} placeholder="Email" />
#         {errors.email && <Typography color="error">{errors.email.message}</Typography>}
#       </Box>
#       <Box mb={2}>
#         <input {...register('password', { required: true })} type="password" placeholder="Password" />
#         {errors.password && <Typography color="error">{errors.password.message}</Typography>}
#       </Box>
#       <Button type="submit" variant="contained" color="primary">
#         Login
#       </Button>
#     </form>
#   );
# };
#
# // Similar components for Register and Logout can be implemented
#
# // File Upload Component
# const FileInput = ({ onUpload }) => {
#   const [files, setFiles] = useState([]);
#
#   const handleChange = (e) => {
#     setFiles(e.target.files);
#   };
#
#   const handleSubmit = (e) => {
#     e.preventDefault();
#     const formData = new FormData();
#     files.forEach((file) => formData.append('file', file));
#     axios.post('/api/upload', formData, {
#       onUploadProgress: (progressEvent) => {
#         const percentCompleted = Math.round((progressEvent.loaded * 100) / progressEvent.total);
#         setFiles([...files, { ...file, percent: percentCompleted }]);
#       },
#     }).then(onUpload).catch((error) => {
#       alert('Upload failed. Please try again.');
#     });
#   };
#
#   return (
#     <form onSubmit={handleSubmit}>
#       <input type="file" multiple onChange={handleChange} />
#       <Button type="submit" variant="contained" color="primary">
#         Upload
#       </Button>
#     </form>
#   );
# };
#
# // Similar components for FileList, FileProcessing, and FileDownload can be implemented
#
# // App Component
# const App = () => {
#   const [isAuthenticated, setIsAuthenticated] = useState(false);
#
#   useEffect(() => {
#     const token = localStorage.getItem('token');
#     if (token) {
#       axios.get('/api/token-validation', { headers: { Authorization: token } }).then((response) => {
#         setIsAuthenticated(true);
#       });
#     }
#   }, [isAuthenticated]);
#
#   const handleLogin = (token) => {
#     localStorage.setItem('token', token);
#     setIsAuthenticated(true);
#   };
#
#   return (
#     <Router>
#       <Navigation isAuthenticated={isAuthenticated} />
#       <Switch>
#         <Route path="/login" component={Login} />
#         <Route path="/register" component={Register} />
#         <Route path="/upload" component={FileInput} />
#         <Route path="/files" component={FileList} />
#         <Route path="/process" component={FileProcessing} />
#         <Route path="/download" component={FileDownload} />
#         <Route path="/" exact component={() => <Typography variant="h5">Home</Typography>} />
#         <Route component={() => <Typography variant="h5">404 - Page Not Found</Typography>} />
#       </Switch>
#     </Router>
#   );
# };
#
# export default App;
# ```
#
# This code provides a basic structure for the specified React.js components. You'll need to implement the actual file processing logic, password hashing, and file ID generation according to your specific requirements. Also, remember to replace the placeholder API endpoints with your actual backend endpoints.
#
# Please note that this is a simplified example and does not include error handling, input validation, or security measures that would be necessary for a production application.
